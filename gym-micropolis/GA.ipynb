# %%
from MicropolisControlScript import Quimby
import numpy as np
from gi.repository import Gtk as gtk
import json

# %% [markdown]
# # Genetic Algorithm to build micropolis city

# %%
q = Quimby(map_w=20,map_h=20,gen_size=10,n_population=300,n_steps_evaluation=50)

# %%
# %%capture
q.evaluate_all()

# %%
b = q.genomes[np.argmax(q.populations)]

# %%
b
# Out:
# [[9, 7, 'Residential'],
#  [16, 6, 'Residential'],
#  [12, 19, 'NuclearPowerPlant'],
#  [18, 11, 'Road'],
#  [6, 6, 'Industrial'],
#  [18, 5, 'Residential'],
#  [9, 9, 'Commercial'],
#  [3, 9, 'NuclearPowerPlant'],
#  [18, 8, 'NuclearPowerPlant'],
#  [9, 9, 'Commercial']]

# %%
gtk.events_pending()
# Out:
# True

# %%
gtk.main_iteration()
# Out:
# True

# %%
m.render()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1184
# -> 1185     def invokeCallback(self, micropolis, name, *args):
#    1186         # In this case, micropolis is the same as self, so ignore it.
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# ...
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgenericengine.py in invokeCallback(self, micropolis, name, *args)
#    1186         # In this case, micropolis is the same as self, so ignore it.
# -> 1187         handler = getattr(self, 'handle_' + name, None)
#    1188         if handler:
#
# SystemError: <built-in function getattr> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgtkengine.py in tickTimer(self)
#     532         self.stopTimer()
#     533
# --> 534         self.tickEngine()
#     535
#     536         if self.running:
#
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisgtkengine.py in tickEngine(self)
#     542     def tickEngine(self):
#     543
# --> 544         self.simTick()
#     545         if self.doAnimation and not self.tilesAnimated:
#     546             self.animateTiles()
#
# ~/Desktop/Machine Learning Term Project/gym-micropolis/micropolis/MicropolisCore/src/pyMicropolis/micropolisEngine/micropolisengine.py in simTick(self)
#    1257
#    1258     def simTick(self) -> "void":
# -> 1259         return _micropolisengine.Micropolis_simTick(self)
#    1260
#    1261     def simRobots(self) -> "void":
#
# SystemError: <built-in function Micropolis_simTick> returned a result with an error set
